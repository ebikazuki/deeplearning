# %%
# %matplotlib inline

#必要なライブラリをインポート
import numpy as np
import matplotlib.pylab as plt

#ステップ関数を定義
def step(x):
    x = x > 0
    return x.astype(np.int)

#グラフを表示
X = np.arange(-10, 10, 0.1)
Y = step(X)
plt.plot(X, Y)
plt.ylim(-0.1, 1.1)
plt.show()

# %%
# %matplotlib inline

#必要なライブラリをインポート
import numpy as np
import matplotlib.pylab as plt

#シグモイド関数を定義
def sigmoid(x):
    return 1 / (1 + np.exp(-x))    

#グラフを表示
X = np.arange(-10, 10, 0.1)
Y = sigmoid(X)
plt.plot(X, Y)
plt.ylim(-0.1, 1.1)
plt.show()

# %%
# %matplotlib inline

#必要なライブラリをインポート
import numpy as np
import matplotlib.pylab as plt

#ReLU関数を定義
def relu(x):
    return np.maximum(0, x)

#グラフを表示
x = np.arange(-10, 10, 0.1)
y = relu(x)
plt.plot(x, y)
plt.ylim(-1.0, 10.5)
plt.show()
