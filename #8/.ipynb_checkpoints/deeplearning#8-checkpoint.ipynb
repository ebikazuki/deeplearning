# %%
#Weight Decayあり
# %matplotlib inline
import os
import sys

sys.path.append(os.pardir)  # 親ディレクトリのファイルをインポートするための設定
import numpy as np
import matplotlib.pyplot as plt
from dataset.mnist import load_mnist
from common.multi_layer_net import MultiLayerNet
from common.optimizer import SGD

(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True)

# 過学習を再現するために、学習データを削減
x_train = x_train[:100]
t_train = t_train[:100]

# weight decay（荷重減衰）の設定 =======================
#weight_decay_lambda = 0 # weight decayを使用しない場合
weight_decay_lambda = 0.05
# ====================================================

network = MultiLayerNet(input_size=784, hidden_size_list=[100, 100, 100, 100, 100, 100], output_size=10,
                        weight_decay_lambda=weight_decay_lambda)
optimizer = SGD(lr=0.01)

max_epochs = 201
train_size = x_train.shape[0]
batch_size = 100

train_loss_list = []
train_acc_list = []
test_acc_list = []

iter_per_epoch = max(train_size / batch_size, 1)
epoch_cnt = 0

for i in range(1000000000):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    t_batch = t_train[batch_mask]

    grads = network.gradient(x_batch, t_batch)
    optimizer.update(network.params, grads)

    if i % iter_per_epoch == 0:
        train_acc = network.accuracy(x_train, t_train)
        test_acc = network.accuracy(x_test, t_test)
        train_acc_list.append(train_acc)
        test_acc_list.append(test_acc)

        print("epoch:" + str(epoch_cnt) + ", train acc:" + str(train_acc) + ", test acc:" + str(test_acc))

        epoch_cnt += 1
        if epoch_cnt >= max_epochs:
            break


# 3.グラフの描画==========
markers = {'train': 'o', 'test': 's'}
x = np.arange(max_epochs)
plt.plot(x, train_acc_list, marker='o', label='train', markevery=10)
plt.plot(x, test_acc_list, marker='s', label='test', markevery=10)
plt.xlabel("epochs")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
plt.legend(loc='lower right')
plt.show()
# Out:
# epoch:0, train acc:0.13, test acc:0.0989
# epoch:1, train acc:0.18, test acc:0.1027
# epoch:2, train acc:0.18, test acc:0.1064
# epoch:3, train acc:0.18, test acc:0.1118
# epoch:4, train acc:0.21, test acc:0.1105
# epoch:5, train acc:0.23, test acc:0.1165
# epoch:6, train acc:0.23, test acc:0.1204
# epoch:7, train acc:0.22, test acc:0.1187
# epoch:8, train acc:0.25, test acc:0.1214
# epoch:9, train acc:0.24, test acc:0.1231
# epoch:10, train acc:0.24, test acc:0.126
# epoch:11, train acc:0.26, test acc:0.1275
# epoch:12, train acc:0.26, test acc:0.1298
# epoch:13, train acc:0.26, test acc:0.1326
# epoch:14, train acc:0.28, test acc:0.1357
# epoch:15, train acc:0.29, test acc:0.139
# epoch:16, train acc:0.3, test acc:0.1415
# epoch:17, train acc:0.34, test acc:0.1487
# epoch:18, train acc:0.36, test acc:0.1523
# epoch:19, train acc:0.33, test acc:0.1508
# epoch:20, train acc:0.33, test acc:0.1535
# epoch:21, train acc:0.35, test acc:0.1614
# epoch:22, train acc:0.35, test acc:0.1627
# epoch:23, train acc:0.35, test acc:0.1636
# epoch:24, train acc:0.37, test acc:0.1814
# epoch:25, train acc:0.38, test acc:0.1798
# epoch:26, train acc:0.38, test acc:0.1891
# epoch:27, train acc:0.38, test acc:0.1924
# epoch:28, train acc:0.39, test acc:0.1921
# epoch:29, train acc:0.4, test acc:0.1893
# epoch:30, train acc:0.4, test acc:0.1935
# epoch:31, train acc:0.4, test acc:0.2074
# epoch:32, train acc:0.41, test acc:0.2157
# epoch:33, train acc:0.42, test acc:0.2131
# epoch:34, train acc:0.42, test acc:0.2105
# epoch:35, train acc:0.42, test acc:0.2309
# epoch:36, train acc:0.41, test acc:0.2235
# epoch:37, train acc:0.42, test acc:0.234
# epoch:38, train acc:0.43, test acc:0.2421
# epoch:39, train acc:0.43, test acc:0.2441
# epoch:40, train acc:0.43, test acc:0.2465
# epoch:41, train acc:0.43, test acc:0.2386
# epoch:42, train acc:0.43, test acc:0.2503
# epoch:43, train acc:0.44, test acc:0.2539
# epoch:44, train acc:0.48, test acc:0.2669
# epoch:45, train acc:0.46, test acc:0.2704
# epoch:46, train acc:0.48, test acc:0.2815
# epoch:47, train acc:0.48, test acc:0.2846
# epoch:48, train acc:0.48, test acc:0.284
# epoch:49, train acc:0.49, test acc:0.2931
# epoch:50, train acc:0.51, test acc:0.2996
# epoch:51, train acc:0.52, test acc:0.3022
# epoch:52, train acc:0.51, test acc:0.3004
# epoch:53, train acc:0.54, test acc:0.3054
# epoch:54, train acc:0.58, test acc:0.3238
# epoch:55, train acc:0.57, test acc:0.3297
# epoch:56, train acc:0.6, test acc:0.3323
# epoch:57, train acc:0.61, test acc:0.3394
# epoch:58, train acc:0.61, test acc:0.3574
# epoch:59, train acc:0.63, test acc:0.3597
# epoch:60, train acc:0.64, test acc:0.365
# epoch:61, train acc:0.64, test acc:0.3705
# epoch:62, train acc:0.63, test acc:0.3751
# epoch:63, train acc:0.63, test acc:0.3798
# epoch:64, train acc:0.63, test acc:0.3801
# epoch:65, train acc:0.65, test acc:0.3825
# epoch:66, train acc:0.66, test acc:0.3862
# epoch:67, train acc:0.63, test acc:0.3886
# epoch:68, train acc:0.67, test acc:0.3913
# epoch:69, train acc:0.66, test acc:0.3875
# epoch:70, train acc:0.68, test acc:0.3965
# epoch:71, train acc:0.68, test acc:0.4038
# epoch:72, train acc:0.68, test acc:0.4084
# epoch:73, train acc:0.73, test acc:0.4123
# epoch:74, train acc:0.73, test acc:0.4093
# epoch:75, train acc:0.72, test acc:0.4079
# epoch:76, train acc:0.73, test acc:0.4156
# epoch:77, train acc:0.72, test acc:0.4132
# epoch:78, train acc:0.74, test acc:0.4173
# epoch:79, train acc:0.74, test acc:0.4222
# epoch:80, train acc:0.74, test acc:0.4278
# epoch:81, train acc:0.76, test acc:0.4337
# epoch:82, train acc:0.76, test acc:0.433
# epoch:83, train acc:0.77, test acc:0.436
# epoch:84, train acc:0.77, test acc:0.4332
# epoch:85, train acc:0.78, test acc:0.4372
# epoch:86, train acc:0.78, test acc:0.436
# epoch:87, train acc:0.78, test acc:0.4414
# epoch:88, train acc:0.79, test acc:0.4446
# epoch:89, train acc:0.78, test acc:0.4526
# epoch:90, train acc:0.79, test acc:0.4522
# epoch:91, train acc:0.8, test acc:0.4559
# epoch:92, train acc:0.8, test acc:0.46
# epoch:93, train acc:0.8, test acc:0.4684
# epoch:94, train acc:0.82, test acc:0.4628
# epoch:95, train acc:0.81, test acc:0.4714
# epoch:96, train acc:0.82, test acc:0.4711
# epoch:97, train acc:0.81, test acc:0.4682
# epoch:98, train acc:0.81, test acc:0.4788
# epoch:99, train acc:0.81, test acc:0.4806
# epoch:100, train acc:0.81, test acc:0.472
# epoch:101, train acc:0.8, test acc:0.4691
# epoch:102, train acc:0.8, test acc:0.4706
# epoch:103, train acc:0.8, test acc:0.4793
# epoch:104, train acc:0.8, test acc:0.4875
# epoch:105, train acc:0.79, test acc:0.4805
# epoch:106, train acc:0.8, test acc:0.4825
# epoch:107, train acc:0.82, test acc:0.4807
# epoch:108, train acc:0.82, test acc:0.4807
# epoch:109, train acc:0.82, test acc:0.4888
# epoch:110, train acc:0.81, test acc:0.4949
# epoch:111, train acc:0.83, test acc:0.4944
# epoch:112, train acc:0.8, test acc:0.4938
# epoch:113, train acc:0.82, test acc:0.5022
# epoch:114, train acc:0.82, test acc:0.4995
# epoch:115, train acc:0.82, test acc:0.5033
# epoch:116, train acc:0.81, test acc:0.5058
# epoch:117, train acc:0.81, test acc:0.504
# epoch:118, train acc:0.84, test acc:0.5107
# epoch:119, train acc:0.84, test acc:0.5163
# epoch:120, train acc:0.87, test acc:0.5156
# epoch:121, train acc:0.85, test acc:0.5145
# epoch:122, train acc:0.84, test acc:0.5192
# epoch:123, train acc:0.85, test acc:0.518
# epoch:124, train acc:0.85, test acc:0.5155
# epoch:125, train acc:0.84, test acc:0.518
# epoch:126, train acc:0.86, test acc:0.5261
# epoch:127, train acc:0.85, test acc:0.5259
# epoch:128, train acc:0.85, test acc:0.5247
# epoch:129, train acc:0.86, test acc:0.5295
# epoch:130, train acc:0.85, test acc:0.5287
# epoch:131, train acc:0.86, test acc:0.5283
# epoch:132, train acc:0.85, test acc:0.5311
# epoch:133, train acc:0.84, test acc:0.5295
# epoch:134, train acc:0.84, test acc:0.53
# epoch:135, train acc:0.84, test acc:0.5319
# epoch:136, train acc:0.84, test acc:0.5303
# epoch:137, train acc:0.85, test acc:0.5351
# epoch:138, train acc:0.84, test acc:0.5295
# epoch:139, train acc:0.84, test acc:0.5302
# epoch:140, train acc:0.84, test acc:0.5381
# epoch:141, train acc:0.86, test acc:0.5372
# epoch:142, train acc:0.84, test acc:0.5365
# epoch:143, train acc:0.86, test acc:0.5425
# epoch:144, train acc:0.85, test acc:0.5363
# epoch:145, train acc:0.84, test acc:0.54
# epoch:146, train acc:0.85, test acc:0.5393
# epoch:147, train acc:0.86, test acc:0.5483
# epoch:148, train acc:0.86, test acc:0.5428
# epoch:149, train acc:0.86, test acc:0.5507
# epoch:150, train acc:0.87, test acc:0.55
# epoch:151, train acc:0.87, test acc:0.5556
# epoch:152, train acc:0.86, test acc:0.5565
# epoch:153, train acc:0.86, test acc:0.5562
# epoch:154, train acc:0.85, test acc:0.5505
# epoch:155, train acc:0.85, test acc:0.5512
# epoch:156, train acc:0.86, test acc:0.5518
# epoch:157, train acc:0.87, test acc:0.5612
# epoch:158, train acc:0.88, test acc:0.5626
# epoch:159, train acc:0.9, test acc:0.5617
# epoch:160, train acc:0.89, test acc:0.5636
# epoch:161, train acc:0.89, test acc:0.5643
# epoch:162, train acc:0.88, test acc:0.5705
# epoch:163, train acc:0.87, test acc:0.5678
# epoch:164, train acc:0.87, test acc:0.5709
# epoch:165, train acc:0.9, test acc:0.5726
# epoch:166, train acc:0.92, test acc:0.5759
# epoch:167, train acc:0.92, test acc:0.5747
# epoch:168, train acc:0.91, test acc:0.5745
# epoch:169, train acc:0.92, test acc:0.5739
# epoch:170, train acc:0.92, test acc:0.5732
# epoch:171, train acc:0.92, test acc:0.5711
# epoch:172, train acc:0.93, test acc:0.5737
# epoch:173, train acc:0.93, test acc:0.579
# epoch:174, train acc:0.93, test acc:0.5714
# epoch:175, train acc:0.93, test acc:0.5784
# epoch:176, train acc:0.94, test acc:0.5767
# epoch:177, train acc:0.95, test acc:0.5769
# epoch:178, train acc:0.95, test acc:0.5807
# epoch:179, train acc:0.94, test acc:0.5814
# epoch:180, train acc:0.96, test acc:0.5837
# epoch:181, train acc:0.96, test acc:0.5855
# epoch:182, train acc:0.96, test acc:0.5833
# epoch:183, train acc:0.95, test acc:0.5852
# epoch:184, train acc:0.96, test acc:0.5859
# epoch:185, train acc:0.95, test acc:0.5865
# epoch:186, train acc:0.95, test acc:0.5826
# epoch:187, train acc:0.96, test acc:0.5811
# epoch:188, train acc:0.96, test acc:0.5838
# epoch:189, train acc:0.96, test acc:0.5862
# epoch:190, train acc:0.95, test acc:0.5862
# epoch:191, train acc:0.95, test acc:0.5838
# epoch:192, train acc:0.94, test acc:0.5816
# epoch:193, train acc:0.95, test acc:0.5791
# epoch:194, train acc:0.95, test acc:0.5768
# epoch:195, train acc:0.96, test acc:0.5883
# epoch:196, train acc:0.95, test acc:0.5933
# epoch:197, train acc:0.96, test acc:0.5939
# epoch:198, train acc:0.96, test acc:0.5912
# epoch:199, train acc:0.95, test acc:0.5925
# epoch:200, train acc:0.95, test acc:0.5967

# %%
#Weight Decayなし
# %matplotlib inline
import os
import sys

sys.path.append(os.pardir)  # 親ディレクトリのファイルをインポートするための設定
import numpy as np
import matplotlib.pyplot as plt
from dataset.mnist import load_mnist
from common.multi_layer_net import MultiLayerNet
from common.optimizer import SGD

(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True)

# 過学習を再現するために、学習データを削減
x_train = x_train[:100]
t_train = t_train[:100]

# weight decay（荷重減衰）の設定 =======================
weight_decay_lambda = 0 # weight decayを使用しない場合
#weight_decay_lambda = 0.1
# ====================================================

network = MultiLayerNet(input_size=784, hidden_size_list=[100, 100, 100, 100, 100, 100], output_size=10,
                        weight_decay_lambda=weight_decay_lambda)
optimizer = SGD(lr=0.01)

max_epochs = 201
train_size = x_train.shape[0]
batch_size = 100

train_loss_list = []
train_acc_list = []
test_acc_list = []

iter_per_epoch = max(train_size / batch_size, 1)
epoch_cnt = 0

for i in range(1000000000):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    t_batch = t_train[batch_mask]

    grads = network.gradient(x_batch, t_batch)
    optimizer.update(network.params, grads)

    if i % iter_per_epoch == 0:
        train_acc = network.accuracy(x_train, t_train)
        test_acc = network.accuracy(x_test, t_test)
        train_acc_list.append(train_acc)
        test_acc_list.append(test_acc)

        print("epoch:" + str(epoch_cnt) + ", train acc:" + str(train_acc) + ", test acc:" + str(test_acc))

        epoch_cnt += 1
        if epoch_cnt >= max_epochs:
            break


# 3.グラフの描画==========
markers = {'train': 'o', 'test': 's'}
x = np.arange(max_epochs)
plt.plot(x, train_acc_list, marker='o', label='train', markevery=10)
plt.plot(x, test_acc_list, marker='s', label='test', markevery=10)
plt.xlabel("epochs")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
plt.legend(loc='lower right')
plt.show()
# Out:
# epoch:0, train acc:0.11, test acc:0.0966
# epoch:1, train acc:0.12, test acc:0.0977
# epoch:2, train acc:0.12, test acc:0.0979
# epoch:3, train acc:0.12, test acc:0.0995
# epoch:4, train acc:0.12, test acc:0.1015
# epoch:5, train acc:0.13, test acc:0.1036
# epoch:6, train acc:0.15, test acc:0.1067
# epoch:7, train acc:0.16, test acc:0.1089
# epoch:8, train acc:0.2, test acc:0.1132
# epoch:9, train acc:0.2, test acc:0.1154
# epoch:10, train acc:0.19, test acc:0.1155
# epoch:11, train acc:0.2, test acc:0.1173
# epoch:12, train acc:0.21, test acc:0.1197
# epoch:13, train acc:0.22, test acc:0.1235
# epoch:14, train acc:0.24, test acc:0.1294
# epoch:15, train acc:0.26, test acc:0.1334
# epoch:16, train acc:0.25, test acc:0.1342
# epoch:17, train acc:0.26, test acc:0.1395
# epoch:18, train acc:0.26, test acc:0.1419
# epoch:19, train acc:0.26, test acc:0.1405
# epoch:20, train acc:0.26, test acc:0.14
# epoch:21, train acc:0.27, test acc:0.1436
# epoch:22, train acc:0.27, test acc:0.146
# epoch:23, train acc:0.3, test acc:0.1483
# epoch:24, train acc:0.34, test acc:0.1542
# epoch:25, train acc:0.33, test acc:0.1536
# epoch:26, train acc:0.31, test acc:0.1592
# epoch:27, train acc:0.33, test acc:0.1627
# epoch:28, train acc:0.33, test acc:0.1641
# epoch:29, train acc:0.37, test acc:0.1666
# epoch:30, train acc:0.4, test acc:0.1729
# epoch:31, train acc:0.41, test acc:0.1773
# epoch:32, train acc:0.43, test acc:0.1779
# epoch:33, train acc:0.43, test acc:0.1798
# epoch:34, train acc:0.42, test acc:0.1808
# epoch:35, train acc:0.48, test acc:0.19
# epoch:36, train acc:0.48, test acc:0.1903
# epoch:37, train acc:0.48, test acc:0.2021
# epoch:38, train acc:0.47, test acc:0.2046
# epoch:39, train acc:0.5, test acc:0.201
# epoch:40, train acc:0.49, test acc:0.2037
# epoch:41, train acc:0.5, test acc:0.2054
# epoch:42, train acc:0.52, test acc:0.2171
# epoch:43, train acc:0.54, test acc:0.2195
# epoch:44, train acc:0.52, test acc:0.2214
# epoch:45, train acc:0.54, test acc:0.2251
# epoch:46, train acc:0.56, test acc:0.2306
# epoch:47, train acc:0.58, test acc:0.2478
# epoch:48, train acc:0.59, test acc:0.2543
# epoch:49, train acc:0.6, test acc:0.2637
# epoch:50, train acc:0.61, test acc:0.2698
# epoch:51, train acc:0.63, test acc:0.2725
# epoch:52, train acc:0.62, test acc:0.2737
# epoch:53, train acc:0.61, test acc:0.2811
# epoch:54, train acc:0.64, test acc:0.2877
# epoch:55, train acc:0.66, test acc:0.298
# epoch:56, train acc:0.66, test acc:0.3022
# epoch:57, train acc:0.65, test acc:0.3157
# epoch:58, train acc:0.66, test acc:0.3104
# epoch:59, train acc:0.67, test acc:0.327
# epoch:60, train acc:0.67, test acc:0.3371
# epoch:61, train acc:0.66, test acc:0.345
# epoch:62, train acc:0.67, test acc:0.3509
# epoch:63, train acc:0.71, test acc:0.3584
# epoch:64, train acc:0.7, test acc:0.3563
# epoch:65, train acc:0.69, test acc:0.3604
# epoch:66, train acc:0.7, test acc:0.3707
# epoch:67, train acc:0.74, test acc:0.3766
# epoch:68, train acc:0.76, test acc:0.3872
# epoch:69, train acc:0.74, test acc:0.3971
# epoch:70, train acc:0.76, test acc:0.3943
# epoch:71, train acc:0.76, test acc:0.4001
# epoch:72, train acc:0.75, test acc:0.4045
# epoch:73, train acc:0.78, test acc:0.4079
# epoch:74, train acc:0.77, test acc:0.4189
# epoch:75, train acc:0.8, test acc:0.4211
# epoch:76, train acc:0.81, test acc:0.422
# epoch:77, train acc:0.82, test acc:0.4329
# epoch:78, train acc:0.8, test acc:0.4333
# epoch:79, train acc:0.8, test acc:0.4443
# epoch:80, train acc:0.81, test acc:0.4391
# epoch:81, train acc:0.83, test acc:0.4477
# epoch:82, train acc:0.83, test acc:0.4458
# epoch:83, train acc:0.86, test acc:0.4447
# epoch:84, train acc:0.86, test acc:0.4617
# epoch:85, train acc:0.87, test acc:0.4717
# epoch:86, train acc:0.9, test acc:0.4729
# epoch:87, train acc:0.89, test acc:0.4721
# epoch:88, train acc:0.85, test acc:0.4694
# epoch:89, train acc:0.89, test acc:0.4813
# epoch:90, train acc:0.88, test acc:0.4828
# epoch:91, train acc:0.89, test acc:0.4891
# epoch:92, train acc:0.9, test acc:0.4876
# epoch:93, train acc:0.91, test acc:0.4985
# epoch:94, train acc:0.92, test acc:0.502
# epoch:95, train acc:0.93, test acc:0.4941
# epoch:96, train acc:0.92, test acc:0.4946
# epoch:97, train acc:0.91, test acc:0.4941
# epoch:98, train acc:0.91, test acc:0.4894
# epoch:99, train acc:0.91, test acc:0.4933
# epoch:100, train acc:0.91, test acc:0.4879
# epoch:101, train acc:0.91, test acc:0.4935
# epoch:102, train acc:0.92, test acc:0.4942
# epoch:103, train acc:0.92, test acc:0.4988
# epoch:104, train acc:0.93, test acc:0.5129
# epoch:105, train acc:0.92, test acc:0.5142
# epoch:106, train acc:0.93, test acc:0.5134
# epoch:107, train acc:0.92, test acc:0.5107
# epoch:108, train acc:0.94, test acc:0.5219
# epoch:109, train acc:0.94, test acc:0.5155
# epoch:110, train acc:0.94, test acc:0.521
# epoch:111, train acc:0.93, test acc:0.5225
# epoch:112, train acc:0.94, test acc:0.5225
# epoch:113, train acc:0.95, test acc:0.5216
# epoch:114, train acc:0.95, test acc:0.5251
# epoch:115, train acc:0.96, test acc:0.521
# epoch:116, train acc:0.96, test acc:0.5214
# epoch:117, train acc:0.96, test acc:0.5212
# epoch:118, train acc:0.96, test acc:0.5173
# epoch:119, train acc:0.96, test acc:0.527
# epoch:120, train acc:0.95, test acc:0.5376
# epoch:121, train acc:0.95, test acc:0.5342
# epoch:122, train acc:0.96, test acc:0.5303
# epoch:123, train acc:0.96, test acc:0.5353
# epoch:124, train acc:0.96, test acc:0.5469
# epoch:125, train acc:0.96, test acc:0.545
# epoch:126, train acc:0.96, test acc:0.5467
# epoch:127, train acc:0.96, test acc:0.5402
# epoch:128, train acc:0.96, test acc:0.5382
# epoch:129, train acc:0.96, test acc:0.5432
# epoch:130, train acc:0.96, test acc:0.5366
# epoch:131, train acc:0.96, test acc:0.5445
# epoch:132, train acc:0.96, test acc:0.5486
# epoch:133, train acc:0.96, test acc:0.5507
# epoch:134, train acc:0.96, test acc:0.5496
# epoch:135, train acc:0.96, test acc:0.5439
# epoch:136, train acc:0.96, test acc:0.5488
# epoch:137, train acc:0.97, test acc:0.5478
# epoch:138, train acc:0.97, test acc:0.5496
# epoch:139, train acc:0.97, test acc:0.5439
# epoch:140, train acc:0.98, test acc:0.5467
# epoch:141, train acc:0.98, test acc:0.549
# epoch:142, train acc:0.98, test acc:0.5536
# epoch:143, train acc:0.98, test acc:0.5522
# epoch:144, train acc:0.98, test acc:0.5467
# epoch:145, train acc:0.98, test acc:0.5516
# epoch:146, train acc:0.98, test acc:0.5513
# epoch:147, train acc:0.98, test acc:0.5516
# epoch:148, train acc:0.98, test acc:0.5563
# epoch:149, train acc:0.98, test acc:0.5554
# epoch:150, train acc:0.98, test acc:0.5581
# epoch:151, train acc:0.99, test acc:0.5637
# epoch:152, train acc:0.99, test acc:0.5656
# epoch:153, train acc:0.99, test acc:0.5636
# epoch:154, train acc:0.99, test acc:0.5662
# epoch:155, train acc:0.99, test acc:0.5579
# epoch:156, train acc:0.99, test acc:0.5569
# epoch:157, train acc:0.99, test acc:0.5601
# epoch:158, train acc:0.99, test acc:0.5585
# epoch:159, train acc:0.99, test acc:0.56
# epoch:160, train acc:0.99, test acc:0.5668
# epoch:161, train acc:1.0, test acc:0.5656
# epoch:162, train acc:0.99, test acc:0.5656
# epoch:163, train acc:1.0, test acc:0.5689
# epoch:164, train acc:1.0, test acc:0.5735
# epoch:165, train acc:0.99, test acc:0.5725
# epoch:166, train acc:0.99, test acc:0.5676
# epoch:167, train acc:0.99, test acc:0.5667
# epoch:168, train acc:0.99, test acc:0.5663
# epoch:169, train acc:0.99, test acc:0.5659
# epoch:170, train acc:0.99, test acc:0.5693
# epoch:171, train acc:0.99, test acc:0.5695
# epoch:172, train acc:1.0, test acc:0.5713
# epoch:173, train acc:0.99, test acc:0.577
# epoch:174, train acc:1.0, test acc:0.5774
# epoch:175, train acc:1.0, test acc:0.5774
# epoch:176, train acc:1.0, test acc:0.5743
# epoch:177, train acc:1.0, test acc:0.5745
# epoch:178, train acc:1.0, test acc:0.5761
# epoch:179, train acc:1.0, test acc:0.5784
# epoch:180, train acc:1.0, test acc:0.5784
# epoch:181, train acc:1.0, test acc:0.5766
# epoch:182, train acc:1.0, test acc:0.5768
# epoch:183, train acc:1.0, test acc:0.5758
# epoch:184, train acc:1.0, test acc:0.5798
# epoch:185, train acc:1.0, test acc:0.5833
# epoch:186, train acc:1.0, test acc:0.5827
# epoch:187, train acc:1.0, test acc:0.5785
# epoch:188, train acc:1.0, test acc:0.5779
# epoch:189, train acc:1.0, test acc:0.5772
# epoch:190, train acc:1.0, test acc:0.5789
# epoch:191, train acc:1.0, test acc:0.5778
# epoch:192, train acc:1.0, test acc:0.581
# epoch:193, train acc:1.0, test acc:0.5812
# epoch:194, train acc:1.0, test acc:0.5844
# epoch:195, train acc:1.0, test acc:0.584
# epoch:196, train acc:1.0, test acc:0.5826
# epoch:197, train acc:1.0, test acc:0.5835
# epoch:198, train acc:1.0, test acc:0.5848
# epoch:199, train acc:1.0, test acc:0.5879
# epoch:200, train acc:1.0, test acc:0.5861

# %%
import numpy as np

a=np.random.randn(5,5)

print(np.std(a))
print(np.average(a))
print(sum(a))
a
# Out:
# 0.9244978831279251
# 0.04378589971316335
# [-3.46997279 -0.65850135  1.3191361   1.13644244  2.76754309]
# array([[-1.43202373, -1.10656849,  0.2729797 ,  0.5350266 ,  0.89945765],
#        [-1.32578502, -0.38791643, -0.15109236,  1.12554683,  1.08674063],
#        [ 0.83926519,  0.92982307,  0.28098189,  0.26272615, -0.07285569],
#        [-0.39201637, -1.48711674, -0.34939219,  0.38965684, -0.46559075],
#        [-1.15941285,  1.39327723,  1.26565906, -1.17651398,  1.31979125]])

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt


def sigmoid(x):
    return 1 / (1 + np.exp(-x))


def ReLU(x):
    return np.maximum(0, x)


def tanh(x):
    return np.tanh(x)
    
input_data = np.random.randn(1, 100)  # 1000個のデータ
node_num = 100  # 各隠れ層のノード（ニューロン）の数
hidden_layer_size = 5  # 隠れ層が5層
activations = {}  # ここにアクティベーションの結果を格納する

x = input_data

for i in range(hidden_layer_size):
    if i != 0:
        x = activations[i-1]

    # 初期値の値をいろいろ変えて実験しよう！
    #w = np.random.randn(node_num, node_num) * 1
    w = np.random.randn(node_num, node_num) * 0.01
    # w = np.random.randn(node_num, node_num) * np.sqrt(1.0 / node_num)
    # w = np.random.randn(node_num, node_num) * np.sqrt(2.0 / node_num)


    a = np.dot(x, w)


    # 活性化関数の種類も変えて実験しよう！
    z = sigmoid(a)
    # z = ReLU(a)
    # z = tanh(a)

    activations[i] = z

# ヒストグラムを描画
for i, a in activations.items():
    plt.subplot(1, len(activations), i+1)
    plt.title(str(i+1) + "-layer")
    if i != 0: plt.yticks([], [])
    # plt.xlim(0.1, 1)
    # plt.ylim(0, 7000)
    plt.hist(a.flatten(), 30, range=(0,1))
plt.show()
